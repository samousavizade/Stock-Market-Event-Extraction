# %%
# %pip install dadmatools spacy_stanza hazm ipywidgets
# Out:
# Collecting dadmatools
#   Using cached dadmatools-1.4.0-py3-none-any.whl (848 kB)
# Collecting spacy_stanza
#   Using cached spacy_stanza-1.0.1-py3-none-any.whl (9.7 kB)
# Collecting hazm
#   Using cached hazm-0.7.0-py3-none-any.whl (316 kB)
# Collecting ipywidgets
#   Using cached ipywidgets-7.7.0-py2.py3-none-any.whl (123 kB)
# Collecting fasttext==0.9.2
#   Using cached fasttext-0.9.2.tar.gz (68 kB)
# Collecting Deprecated==1.2.6
#   Using cached Deprecated-1.2.6-py2.py3-none-any.whl (8.1 kB)
# Collecting html2text
#   Using cached html2text-2020.1.16-py3-none-any.whl (32 kB)
# Collecting pytorch-transformers>=1.1.0
#   Using cached pytorch_transformers-1.2.0-py3-none-any.whl (176 kB)
# Collecting py7zr==0.17.2
#   Using cached py7zr-0.17.2-py3-none-any.whl (68 kB)
# Collecting transformers==4.9.1
#   Using cached transformers-4.9.1-py3-none-any.whl (2.6 MB)
# Collecting tf-estimator-nightly==2.8.0.dev2021122109
#   Using cached tf_estimator_nightly-2.8.0.dev2021122109-py2.py3-none-any.whl (462 kB)
# Collecting spacy==3.0.0
#   Using cached spacy-3.0.0-cp39-cp39-manylinux2014_x86_64.whl (12.5 MB)
# Collecting h5py>=3.3.0
#   Using cached h5py-3.6.0-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (4.5 MB)
# Collecting hyperopt>=0.2.5
#   Using cached hyperopt-0.2.7-py2.py3-none-any.whl (1.6 MB)
# Collecting folium==0.2.1
#   Using cached folium-0.2.1.tar.gz (69 kB)
# Collecting gensim>=3.6.0
#   Using cached gensim-4.1.2-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (24.0 MB)
# Collecting wiki-dump-reader
#   Using cached wiki-dump-reader-0.0.4.tar.gz (3.4 kB)
# Collecting sklearn>=0.0
#   Using cached sklearn-0.0-py2.py3-none-any.whl
# Collecting tabulate>=0.8.6
#   Using cached tabulate-0.8.9-py3-none-any.whl (25 kB)
# Collecting nltk
#   Using cached nltk-3.7-py3-none-any.whl (1.5 MB)
# Collecting conllu
#   Using cached conllu-4.4.1-py2.py3-none-any.whl (15 kB)
# Collecting pyconll>=3.1.0
#   Using cached pyconll-3.1.0-py3-none-any.whl (26 kB)
# Collecting gdown==4.3.1
#   Using cached gdown-4.3.1-py3-none-any.whl
# Collecting bpemb>=0.3.3
#   Using cached bpemb-0.3.3-py3-none-any.whl (19 kB)
# Collecting torch>=1.7.1
#   Using cached torch-1.11.0-cp39-cp39-manylinux1_x86_64.whl (750.6 MB)
# Collecting segtok==1.5.7
#   Using cached segtok-1.5.7.tar.gz (24 kB)
# Collecting NERDA
#   Using cached NERDA-1.0.0-py3-none-any.whl (23 kB)
# Collecting supar==1.1.2
#   Using cached supar-1.1.2-py3-none-any.whl (87 kB)
# Collecting wrapt<2,>=1.10
#   Using cached wrapt-1.14.0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (77 kB)
# Collecting numpy
#   Using cached numpy-1.22.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
# Collecting pybind11>=2.2
#   Using cached pybind11-2.9.2-py2.py3-none-any.whl (213 kB)
# Requirement already satisfied: setuptools>=0.7.0 in /home/amin/amin/University/Term8/NLP/NLP/.venv_test/lib/python3.9/site-packages (from fasttext==0.9.2->dadmatools) (44.1.1)
# Collecting Jinja2
#   Using cached Jinja2-3.1.1-py3-none-any.whl (132 kB)
# Requirement already satisfied: six in /home/amin/amin/University/Term8/NLP/NLP/.venv_test/lib/python3.9/site-packages (from gdown==4.3.1->dadmatools) (1.16.0)
# Collecting tqdm
#   Using cached tqdm-4.64.0-py2.py3-none-any.whl (78 kB)
# Collecting filelock
#   Using cached filelock-3.6.0-py3-none-any.whl (10.0 kB)
# Collecting beautifulsoup4
#   Using cached beautifulsoup4-4.11.1-py3-none-any.whl (128 kB)
# Collecting requests[socks]
#   Using cached requests-2.27.1-py2.py3-none-any.whl (63 kB)
# Collecting brotli>=1.0.9
#   Using cached Brotli-1.0.9-cp39-cp39-manylinux1_x86_64.whl (357 kB)
# Collecting texttable
#   Using cached texttable-1.6.4-py2.py3-none-any.whl (10 kB)
# Collecting pycryptodomex>=3.6.6
#   Using cached pycryptodomex-3.14.1-cp35-abi3-manylinux2010_x86_64.whl (2.0 MB)
# Collecting pyppmd>=0.17.0
#   Using cached pyppmd-0.18.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (131 kB)
# Collecting pybcj>=0.5.0
#   Using cached pybcj-0.5.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (56 kB)
# Collecting multivolumefile>=0.2.3
#   Using cached multivolumefile-0.2.3-py3-none-any.whl (17 kB)
# Collecting pyzstd>=0.14.4
#   Using cached pyzstd-0.15.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
# Collecting regex
#   Using cached regex-2022.3.15-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (763 kB)
# Collecting thinc<8.1.0,>=8.0.0
#   Using cached thinc-8.0.15-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (661 kB)
# Collecting blis<0.8.0,>=0.4.0
#   Using cached blis-0.7.7-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.9 MB)
# Collecting wasabi<1.1.0,>=0.8.1
#   Using cached wasabi-0.9.1-py3-none-any.whl (26 kB)
# Collecting pathy
#   Using cached pathy-0.6.1-py3-none-any.whl (42 kB)
# Requirement already satisfied: packaging>=20.0 in /home/amin/amin/University/Term8/NLP/NLP/.venv_test/lib/python3.9/site-packages (from spacy==3.0.0->dadmatools) (21.3)
# Collecting srsly<3.0.0,>=2.4.0
#   Downloading srsly-2.4.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (457 kB)
#      |████████████████████████████████| 457 kB 265 kB/s eta 0:00:01
# Collecting pydantic<1.8.0,>=1.7.1
#   Using cached pydantic-1.7.4-cp39-cp39-manylinux2014_x86_64.whl (10.3 MB)
# Collecting catalogue<2.1.0,>=2.0.1
#   Using cached catalogue-2.0.7-py3-none-any.whl (17 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.0
#   Using cached spacy_legacy-3.0.9-py2.py3-none-any.whl (20 kB)
# Collecting murmurhash<1.1.0,>=0.28.0
#   Using cached murmurhash-1.0.6-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (21 kB)
# Collecting typer<0.4.0,>=0.3.0
#   Using cached typer-0.3.2-py3-none-any.whl (21 kB)
# Collecting cymem<2.1.0,>=2.0.2
#   Using cached cymem-2.0.6-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (35 kB)
# Collecting preshed<3.1.0,>=3.0.2
#   Using cached preshed-3.0.6-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (128 kB)
# Collecting stanza
#   Using cached stanza-1.3.0-py3-none-any.whl (432 kB)
# Collecting dill
#   Using cached dill-0.3.4-py2.py3-none-any.whl (86 kB)
# Collecting sacremoses
#   Using cached sacremoses-0.0.49-py3-none-any.whl (895 kB)
# Collecting pyyaml>=5.1
#   Using cached PyYAML-6.0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (661 kB)
# Collecting huggingface-hub==0.0.12
#   Using cached huggingface_hub-0.0.12-py3-none-any.whl (37 kB)
# Collecting tokenizers<0.11,>=0.10.1
#   Using cached tokenizers-0.10.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
# Collecting typing-extensions
#   Using cached typing_extensions-4.1.1-py3-none-any.whl (26 kB)
# Collecting sentencepiece
#   Using cached sentencepiece-0.1.96-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
# Collecting scipy>=0.18.1
#   Using cached scipy-1.8.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (42.1 MB)
# Collecting smart-open>=1.8.1
#   Using cached smart_open-5.2.1-py3-none-any.whl (58 kB)
# Collecting cloudpickle
#   Using cached cloudpickle-2.0.0-py3-none-any.whl (25 kB)
# Collecting future
#   Using cached future-0.18.2.tar.gz (829 kB)
# Collecting py4j
#   Using cached py4j-0.10.9.5-py2.py3-none-any.whl (199 kB)
# Collecting networkx>=2.2
#   Using cached networkx-2.8-py3-none-any.whl (2.0 MB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/amin/amin/University/Term8/NLP/NLP/.venv_test/lib/python3.9/site-packages (from packaging>=20.0->spacy==3.0.0->dadmatools) (3.0.8)
# Collecting boto3
#   Downloading boto3-1.21.41-py3-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 89 kB/s eta 0:00:01
# Collecting charset-normalizer~=2.0.0
#   Using cached charset_normalizer-2.0.12-py3-none-any.whl (39 kB)
# Collecting idna<4,>=2.5
#   Using cached idna-3.3-py3-none-any.whl (61 kB)
# Collecting urllib3<1.27,>=1.21.1
#   Using cached urllib3-1.26.9-py2.py3-none-any.whl (138 kB)
# Collecting certifi>=2017.4.17
#   Using cached certifi-2021.10.8-py2.py3-none-any.whl (149 kB)
# Collecting scikit-learn
#   Using cached scikit_learn-1.0.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (26.4 MB)
# Collecting click<7.2.0,>=7.1.1
#   Using cached click-7.1.2-py2.py3-none-any.whl (82 kB)
# Collecting nltk
#   Using cached nltk-3.3.0.zip (1.4 MB)
# Collecting libwapiti>=0.2.1
#   Using cached libwapiti-0.2.1.tar.gz (233 kB)
# Collecting nbformat>=4.2.0
#   Using cached nbformat-5.3.0-py3-none-any.whl (73 kB)
# Collecting jupyterlab-widgets>=1.0.0
#   Using cached jupyterlab_widgets-1.1.0-py3-none-any.whl (245 kB)
# Requirement already satisfied: traitlets>=4.3.1 in /home/amin/amin/University/Term8/NLP/NLP/.venv_test/lib/python3.9/site-packages (from ipywidgets) (5.1.1)
# Collecting ipython-genutils~=0.2.0
#   Using cached ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: ipython>=4.0.0 in /home/amin/amin/University/Term8/NLP/NLP/.venv_test/lib/python3.9/site-packages (from ipywidgets) (8.2.0)
# Collecting widgetsnbextension~=3.6.0
#   Using cached widgetsnbextension-3.6.0-py2.py3-none-any.whl (1.6 MB)
# Requirement already satisfied: ipykernel>=4.5.1 in /home/amin/amin/University/Term8/NLP/NLP/.venv_test/lib/python3.9/site-packages (from ipywidgets) (6.13.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/amin/amin/University/Term8/NLP/NLP/.venv_test/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (7.2.2)
# Requirement already satisfied: psutil in /home/amin/amin/University/Term8/NLP/NLP/.venv_test/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (5.9.0)
# Requirement already satisfied: tornado>=6.1 in /home/amin/amin/University/Term8/NLP/NLP/.venv_test/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (6.1)
# Requirement already satisfied: nest-asyncio in /home/amin/amin/University/Term8/NLP/NLP/.venv_test/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.5)
# Requirement already satisfied: debugpy>=1.0 in /home/amin/amin/University/Term8/NLP/NLP/.venv_test/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.6.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/amin/amin/University/Term8/NLP/NLP/.venv_test/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.3)
# Requirement already satisfied: pexpect>4.3 in /home/amin/amin/University/Term8/NLP/NLP/.venv_test/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (4.8.0)
# Requirement already satisfied: jedi>=0.16 in /home/amin/amin/University/Term8/NLP/NLP/.venv_test/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (0.18.1)
# Requirement already satisfied: decorator in /home/amin/amin/University/Term8/NLP/NLP/.venv_test/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (5.1.1)
# Requirement already satisfied: backcall in /home/amin/amin/University/Term8/NLP/NLP/.venv_test/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/amin/amin/University/Term8/NLP/NLP/.venv_test/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (3.0.29)
# Requirement already satisfied: stack-data in /home/amin/amin/University/Term8/NLP/NLP/.venv_test/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: pickleshare in /home/amin/amin/University/Term8/NLP/NLP/.venv_test/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (0.7.5)
# Requirement already satisfied: pygments>=2.4.0 in /home/amin/amin/University/Term8/NLP/NLP/.venv_test/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (2.11.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/amin/amin/University/Term8/NLP/NLP/.venv_test/lib/python3.9/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets) (0.8.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/amin/amin/University/Term8/NLP/NLP/.venv_test/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (2.8.2)
# Requirement already satisfied: jupyter-core>=4.9.2 in /home/amin/amin/University/Term8/NLP/NLP/.venv_test/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (4.9.2)
# Requirement already satisfied: entrypoints in /home/amin/amin/University/Term8/NLP/NLP/.venv_test/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (0.4)
# Requirement already satisfied: pyzmq>=22.3 in /home/amin/amin/University/Term8/NLP/NLP/.venv_test/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (22.3.0)
# Collecting fastjsonschema
#   Using cached fastjsonschema-2.15.3-py3-none-any.whl (22 kB)
# Collecting jsonschema>=2.6
#   Using cached jsonschema-4.4.0-py3-none-any.whl (72 kB)
# Collecting attrs>=17.4.0
#   Using cached attrs-21.4.0-py2.py3-none-any.whl (60 kB)
# Collecting pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0
#   Using cached pyrsistent-0.18.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (115 kB)
# Requirement already satisfied: ptyprocess>=0.5 in /home/amin/amin/University/Term8/NLP/NLP/.venv_test/lib/python3.9/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /home/amin/amin/University/Term8/NLP/NLP/.venv_test/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets) (0.2.5)
# Collecting notebook>=4.4.1
#   Using cached notebook-6.4.10-py3-none-any.whl (9.9 MB)
# Collecting argon2-cffi
#   Using cached argon2_cffi-21.3.0-py3-none-any.whl (14 kB)
# Collecting Send2Trash>=1.8.0
#   Using cached Send2Trash-1.8.0-py3-none-any.whl (18 kB)
# Collecting prometheus-client
#   Using cached prometheus_client-0.14.1-py3-none-any.whl (59 kB)
# Collecting terminado>=0.8.3
#   Using cached terminado-0.13.3-py3-none-any.whl (14 kB)
# Collecting nbconvert>=5
#   Using cached nbconvert-6.5.0-py3-none-any.whl (561 kB)
# Collecting tinycss2
#   Using cached tinycss2-1.1.1-py3-none-any.whl (21 kB)
# Collecting nbclient>=0.5.0
#   Downloading nbclient-0.6.0-py3-none-any.whl (70 kB)
#      |████████████████████████████████| 70 kB 72 kB/s eta 0:00:01
# Collecting MarkupSafe>=2.0
#   Using cached MarkupSafe-2.1.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Collecting jupyterlab-pygments
#   Downloading jupyterlab_pygments-0.2.2-py2.py3-none-any.whl (21 kB)
# Collecting defusedxml
#   Using cached defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Collecting pandocfilters>=1.4.1
#   Using cached pandocfilters-1.5.0-py2.py3-none-any.whl (8.7 kB)
# Collecting bleach
#   Using cached bleach-5.0.0-py3-none-any.whl (160 kB)
# Collecting mistune<2,>=0.8.1
#   Using cached mistune-0.8.4-py2.py3-none-any.whl (16 kB)
# Collecting emoji
#   Using cached emoji-1.7.0.tar.gz (175 kB)
# Collecting protobuf
#   Using cached protobuf-3.20.0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
# Collecting argon2-cffi-bindings
#   Using cached argon2_cffi_bindings-21.2.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (86 kB)
# Collecting cffi>=1.0.1
#   Using cached cffi-1.15.0-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (444 kB)
# Collecting pycparser
#   Using cached pycparser-2.21-py2.py3-none-any.whl (118 kB)
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.3.2.post1-py3-none-any.whl (37 kB)
# Collecting webencodings
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Collecting s3transfer<0.6.0,>=0.5.0
#   Using cached s3transfer-0.5.2-py3-none-any.whl (79 kB)
# Collecting jmespath<2.0.0,>=0.7.1
#   Using cached jmespath-1.0.0-py3-none-any.whl (23 kB)
# Collecting botocore<1.25.0,>=1.24.41
#   Downloading botocore-1.24.41-py3-none-any.whl (8.7 MB)
#      |████████████████████████████████| 8.7 MB 165 kB/s eta 0:00:01
# Collecting pandas
#   Using cached pandas-1.4.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.7 MB)
# Collecting progressbar
#   Using cached progressbar-2.5.tar.gz (10 kB)
# Collecting pytz>=2020.1
#   Using cached pytz-2022.1-py2.py3-none-any.whl (503 kB)
# Collecting PySocks!=1.5.7,>=1.5.6
#   Using cached PySocks-1.7.1-py3-none-any.whl (16 kB)
# Collecting joblib
#   Using cached joblib-1.1.0-py2.py3-none-any.whl (306 kB)
# Collecting threadpoolctl>=2.0.0
#   Using cached threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: asttokens in /home/amin/amin/University/Term8/NLP/NLP/.venv_test/lib/python3.9/site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (2.0.5)
# Requirement already satisfied: pure-eval in /home/amin/amin/University/Term8/NLP/NLP/.venv_test/lib/python3.9/site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (0.2.2)
# Requirement already satisfied: executing in /home/amin/amin/University/Term8/NLP/NLP/.venv_test/lib/python3.9/site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (0.8.3)
# Using legacy 'setup.py install' for fasttext, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for folium, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for segtok, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for nltk, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for libwapiti, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for emoji, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for future, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for progressbar, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for wiki-dump-reader, since package 'wheel' is not installed.
# Installing collected packages: pyrsistent, attrs, pycparser, jsonschema, fastjsonschema, webencodings, urllib3, soupsieve, numpy, nbformat, MarkupSafe, jmespath, idna, charset-normalizer, cffi, certifi, typing-extensions, tqdm, tinycss2, threadpoolctl, scipy, requests, regex, pandocfilters, nbclient, murmurhash, mistune, jupyterlab-pygments, joblib, Jinja2, filelock, defusedxml, cymem, click, catalogue, botocore, bleach, beautifulsoup4, argon2-cffi-bindings, wasabi, typer, torch, tokenizers, terminado, srsly, smart-open, Send2Trash, scikit-learn, sacremoses, s3transfer, pyyaml, pytz, PySocks, pydantic, protobuf, prometheus-client, preshed, nbconvert, ipython-genutils, huggingface-hub, emoji, blis, argon2-cffi, wrapt, transformers, thinc, texttable, stanza, spacy-legacy, sklearn, sentencepiece, pyzstd, pyppmd, pycryptodomex, pyconll, pybind11, pybcj, py4j, progressbar, pathy, pandas, notebook, nltk, networkx, multivolumefile, gensim, future, dill, cloudpickle, brotli, boto3, wiki-dump-reader, widgetsnbextension, tf-estimator-nightly, tabulate, supar, spacy, segtok, pytorch-transformers, py7zr, NERDA, libwapiti, jupyterlab-widgets, hyperopt, html2text, h5py, gdown, folium, fasttext, Deprecated, conllu, bpemb, spacy-stanza, ipywidgets, hazm, dadmatools
#     Running setup.py install for emoji ... done
#     Running setup.py install for progressbar ... done
#     Running setup.py install for nltk ... done
#     Running setup.py install for future ... done
#     Running setup.py install for wiki-dump-reader ... done
#     Running setup.py install for segtok ... done
#     Running setup.py install for libwapiti ... done
#     Running setup.py install for folium ... done
#     Running setup.py install for fasttext ... done
# Successfully installed Deprecated-1.2.6 Jinja2-3.1.1 MarkupSafe-2.1.1 NERDA-1.0.0 PySocks-1.7.1 Send2Trash-1.8.0 argon2-cffi-21.3.0 argon2-cffi-bindings-21.2.0 attrs-21.4.0 beautifulsoup4-4.11.1 bleach-5.0.0 blis-0.7.7 boto3-1.21.41 botocore-1.24.41 bpemb-0.3.3 brotli-1.0.9 catalogue-2.0.7 certifi-2021.10.8 cffi-1.15.0 charset-normalizer-2.0.12 click-7.1.2 cloudpickle-2.0.0 conllu-4.4.1 cymem-2.0.6 dadmatools-1.4.0 defusedxml-0.7.1 dill-0.3.4 emoji-1.7.0 fastjsonschema-2.15.3 fasttext-0.9.2 filelock-3.6.0 folium-0.2.1 future-0.18.2 gdown-4.3.1 gensim-4.1.2 h5py-3.6.0 hazm-0.7.0 html2text-2020.1.16 huggingface-hub-0.0.12 hyperopt-0.2.7 idna-3.3 ipython-genutils-0.2.0 ipywidgets-7.7.0 jmespath-1.0.0 joblib-1.1.0 jsonschema-4.4.0 jupyterlab-pygments-0.2.2 jupyterlab-widgets-1.1.0 libwapiti-0.2.1 mistune-0.8.4 multivolumefile-0.2.3 murmurhash-1.0.6 nbclient-0.6.0 nbconvert-6.5.0 nbformat-5.3.0 networkx-2.8 nltk-3.3 notebook-6.4.10 numpy-1.22.3 pandas-1.4.2 pandocfilters-1.5.0 pathy-0.6.1 preshed-3.0.6 progressbar-2.5 prometheus-client-0.14.1 protobuf-3.20.0 py4j-0.10.9.5 py7zr-0.17.2 pybcj-0.5.2 pybind11-2.9.2 pyconll-3.1.0 pycparser-2.21 pycryptodomex-3.14.1 pydantic-1.7.4 pyppmd-0.18.2 pyrsistent-0.18.1 pytorch-transformers-1.2.0 pytz-2022.1 pyyaml-6.0 pyzstd-0.15.2 regex-2022.3.15 requests-2.27.1 s3transfer-0.5.2 sacremoses-0.0.49 scikit-learn-1.0.2 scipy-1.8.0 segtok-1.5.7 sentencepiece-0.1.96 sklearn-0.0 smart-open-5.2.1 soupsieve-2.3.2.post1 spacy-3.0.0 spacy-legacy-3.0.9 spacy-stanza-1.0.1 srsly-2.4.3 stanza-1.3.0 supar-1.1.2 tabulate-0.8.9 terminado-0.13.3 texttable-1.6.4 tf-estimator-nightly-2.8.0.dev2021122109 thinc-8.0.15 threadpoolctl-3.1.0 tinycss2-1.1.1 tokenizers-0.10.3 torch-1.11.0 tqdm-4.64.0 transformers-4.9.1 typer-0.3.2 typing-extensions-4.1.1 urllib3-1.26.9 wasabi-0.9.1 webencodings-0.5.1 widgetsnbextension-3.6.0 wiki-dump-reader-0.0.4 wrapt-1.14.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Read symbols

# %%
import stanza
import spacy_stanza
import re
import json
import pandas as pd
from spacy.tokens import Span
from spacy import displacy
from spacy.symbols import VERB, NOUN, AUX, ADV, ADP

# %%
stanza.install_corenlp()
stanza.download("fa")
stanza_nlp = spacy_stanza.load_pipeline("fa")
# Out:
# 2022-04-15 21:24:16 INFO: Installing CoreNLP package into /home/amin/stanza_corenlp...
# Downloading https://huggingface.co/stanfordnlp/CoreNLP/resolve/main/stanford-corenlp-latest.zip:   0%|        …
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.3.0.json:   0%|   …
# 2022-04-15 22:05:37 INFO: Downloading default packages for language: fa (Persian)...
# Downloading https://huggingface.co/stanfordnlp/stanza-fa/resolve/v1.3.0/models/default.zip:   0%|          | 0…
# 2022-04-15 22:08:37 INFO: Finished downloading models and saved to /home/amin/stanza_resources.
# 2022-04-15 22:08:37 INFO: Loading these models for language: fa (Persian):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | perdt   |
# | mwt       | perdt   |
# | pos       | perdt   |
# | lemma     | perdt   |
# | depparse  | perdt   |
# =======================
#
# 2022-04-15 22:08:37 INFO: Use device: gpu
# 2022-04-15 22:08:37 INFO: Loading: tokenize
# 2022-04-15 22:08:44 INFO: Loading: mwt
# 2022-04-15 22:08:44 INFO: Loading: pos
# 2022-04-15 22:08:45 INFO: Loading: lemma
# 2022-04-15 22:08:45 INFO: Loading: depparse
# 2022-04-15 22:08:45 INFO: Done loading processors!

# %%
df = pd.read_csv("symbols_info.csv", index_col=0)
df["Corp"] = df["Corp. Title"].apply(
    lambda word: re.sub(r"\(.*\)|(ح\.)|(ح\s\.)", "", word).strip()
)
df = df[["Symbol", "Corp"]]
mask = df["Corp"] == df["Symbol"]
df["Corp"][mask] = "شرکت " + df["Corp"]
df.head(n=10)
# Out:
#     Symbol                           Corp
# 0     ثملی  بین المللی ساختمان و صنعت ملی
# 1   اخابرح                  مخابرات ایران
# 2   شتولیح                      تولی‌پرس‌
# 3  دسبحانح                     سبحان دارو
# 4    وزمین                بانک ایران زمین
# 5   سفارسح           سیمان فارس و خوزستان
# 6   فنوالح                نورد آلومینیوم‌
# 7   غالبرح                  لبنیات ‌کالبر
# 8   خساپاح                          سایپا
# 9     مبین           مبین انرژی خلیج فارس

# %%
events = [
    "سود",
    "ضرر",
    "مثبت",
    "منفی",
    "صعود",
    "نزول",
    "افزایش",
    "کاهش",
    "رشد",
    "ریزش",
    "افشا",
    "افشا ب",
    "افشا الف",
    "اصلاح",
    "افت",
    "نوسان",
    "نوسانات",
    "سقوط",
    "تقسیم سود",
    "تعیین نرخ",
    "عرضه اولیه",
    "صف خرید",
    "صف فروش",
    "خروج سرمایه",
    "افزایش سرمایه",
    "خروج پول",
    "مجمع عمومی",
]
announcements = [
    "اطلاعیه",
    "گزارش",
    "اعلامیه",
    "اعلانیه",
]
analyse = [
    "سهم رانتی",
    "تحلیل تکنیکال",
    "تحلیل فاندامنتال",
    "کندل استیک",
    "سیگنال",
    "تکنیکال",
    "کندل",
    "تیک",
    "سرشانه",
    "مقاومت",
    "حمایت",
    "کراس",
    "واگرایی",
    "اندیکاتور",
    "سقف",
    "کف",
    "قیبوناچی",
    "فیبوناتچی",
    "فیبو",
    "کانال",
    "کف‌‌سازی",
    "کف سازی",
    "رنج",
]
characters = [
    "بازیگر",
    "حقیقی",
    "حقوقی",
    "بازی‌گردان",
    "نوسان‌گیر",
]

# %%
from dadmatools.models.normalizer import Normalizer as N1
from hazm import Normalizer as N2

normalizer1 = N1(
    full_cleaning=False,
    unify_chars=True,
    refine_punc_spacing=True,
    remove_extra_space=True,
    remove_puncs=False,
    remove_html=False,
    remove_stop_word=False,
    replace_email_with="<EMAIL>",
    replace_number_with=None,
    replace_url_with="<URL",
    replace_mobile_number_with="<MOBILE_NUMBER>",
    replace_emoji_with="<EMOJI>",
    replace_home_number_with="<HOME_NUMBER>",
)
normalizer2 = N2()

# %%
from spacy.matcher import Matcher

matcher: Matcher = Matcher(stanza_nlp.vocab, validate=True)


def add_patterns(matcher, keywords, class_name):
    keyword_patterns = []
    r = "(ی|ای|یی|ها|هایی|های)?"
    for keyword in keywords:
        keyword_tokens = stanza_nlp.tokenizer(keyword)

        pre_det = ["این", "هر", "چند", "چندین", "آن", "همین", "همان", "چنین", "چنین"]
        if len(keyword_tokens) == 1:
            token1_keyword = keyword_tokens[0].text
            pattern = [
                {"TEXT": {"IN": pre_det}, "OP": "?"},
                {"TEXT": {"REGEX": rf"\b{token1_keyword}{r}\b"}},
                {"TEXT": {"IN": ["ای", "ی", "ها", "های", "هایی"]}, "OP": "?"},
            ]

        elif len(keyword_tokens) == 2:
            token1_keyword = keyword_tokens[0].text
            token2_keyword = keyword_tokens[1].text
            pattern = [
                {"TEXT": {"IN": pre_det}, "OP": "?"},
                {"TEXT": {"REGEX": rf"\b{token1_keyword}{r}\b"}},
                {"TEXT": {"IN": ["ای", "ی", "ها", "های", "هایی"]}, "OP": "?"},
                {"TEXT": {"IN": pre_det}, "OP": "?"},
                {"TEXT": {"REGEX": rf"\b{token2_keyword}{r}\b"}},
                {"TEXT": {"IN": ["ای", "ی", "ها", "های", "هایی"]}, "OP": "?"},
            ]

        keyword_patterns.append(pattern)

    matcher.add(class_name, keyword_patterns, greedy="LONGEST")


SYMBOL = "SYMBOL"
CORP = "CORP"
EVENT = "EVENT"
ANALYSE = "ANALYSE"
ANNOUNCE = "ANNOUNCE"
CHARACTERS = "CHARACTERS"

add_patterns(matcher, events, "EVENT")
add_patterns(matcher, analyse, "ANALYSE")
add_patterns(matcher, announcements, "ANNOUNCE")
add_patterns(matcher, characters, "CHARACTERS")

# %%
symbols = df["Symbol"].tolist()
symbols = list(map(lambda x: x.replace(".", "\\."), symbols))

corporations = df["Corp"].tolist()
corporations = list(map(lambda x: x.replace(".", "\\."), corporations))

# %%
def convert_subtree_to_str(token, remove_ADP=False, is_parent=True):
    extracted_event = ""
    start = None
    end = None
    for x in token.subtree:
        if x.dep_ == "case" and start is None and is_parent:
            continue
        if x.pos == ADV:
            continue
        if remove_ADP and x.pos == ADP and is_parent:
            if x.head.text == token.text:
                if not start is None:
                    print(
                        "WARNING ------------------> check the convert subtree to str"
                    )
                continue

        extracted_event += str(x) + " "
        if start is None:
            start = x.idx
        end = x.idx + len(x.text)

    extracted_event = extracted_event[:-1]
    return extracted_event, start, end


TRANSLATE = {
    SYMBOL: "نماد",
    CORP: "شرکت",
    EVENT: "واقعه",
    ANNOUNCE: "اعلان",
    ANALYSE: "تحلیل",
    CHARACTERS: "شخصیت",
}


def create_output(OUTPUT, output_type, marker, span, **kwargs):
    # print(f'span :{span} , text: "{text[span[0]:span[1]]}" ')
    persian_output_type = TRANSLATE[output_type]
    defaults = {
        "type": persian_output_type,
        "marker": marker,
        "span": span,
    }
    OUTPUT[output_type].append({**defaults, **kwargs})

    return {**defaults, **kwargs}


def concat_tokens(tokens):
    concat = ""
    start = None
    end = None
    for token in tokens:
        if start is None:
            start = token.idx
        substring, s, e = convert_subtree_to_str(token, is_parent=False)
        end = e
        concat += substring + " "
    concat = concat[:-1]
    return concat, start, end


def get_root_string(main_noun):
    left_childs = list(
        filter(lambda x: not x.dep_ in ["cop", "nsubj"], main_noun.lefts)
    )
    right_childs = list(
        filter(lambda x: not x.dep_ in ["cop", "nsubj"], main_noun.rights)
    )
    extracted_event = ""
    start = None
    end = None
    if left_childs:
        substring, s, e = concat_tokens(left_childs)
        if start is None:
            start = s
        end = e
        extracted_event += substring + " "
    extracted_event += main_noun.text
    if start is None:
        start = main_noun.idx
    end = main_noun.idx + len(main_noun.text)

    if right_childs:
        substring, s, e = concat_tokens(right_childs)
        extracted_event += " " + substring
        end = e
    return extracted_event, start, end

# %%
def set_ents(symbols, corporations, doc, matcher, text):
    symbols_expression = "|".join(symbols)
    corporation_expression = "|".join(corporations)

    symbol_spans = list(
        map(
            lambda match: doc.char_span(*match.span(), label=SYMBOL),
            re.finditer(symbols_expression, text),
        )
    )

    symbol_spans = list(filter(lambda span: span is not None, symbol_spans))

    corporation_spans = list(
        map(
            lambda match: doc.char_span(*match.span(), label=CORP),
            re.finditer(corporation_expression, text),
        )
    )

    corporation_spans = list(filter(lambda span: span is not None, corporation_spans))

    term_spans = list(
        map(
            lambda match: Span(
                doc, match[1], match[2], label=stanza_nlp.vocab.strings[match[0]]
            ),
            matcher(doc),
        )
    )

    term_spans = list(filter(lambda span: span is not None, term_spans))

    spans = symbol_spans + corporation_spans + term_spans
    doc.set_ents(spans)

    with doc.retokenize() as retokenizer:
        attrs = {"POS": "NOUN"}
        for span in symbol_spans:
            retokenizer.merge(span, attrs)

    with doc.retokenize() as retokenizer:
        attrs = {"POS": "NOUN"}
        for span in corporation_spans:
            retokenizer.merge(span, attrs)

    with doc.retokenize() as retokenizer:
        attrs = {"POS": "NOUN"}
        for span in term_spans:
            retokenizer.merge(span, attrs)

    return doc

# %%
def find_symbols_and_corporations(doc, output):
    symbol_entities = list(filter(lambda ent: ent.label_ == SYMBOL, doc.ents))

    for symbol_ent in symbol_entities:
        token = symbol_ent[0]
        start = token.idx
        end = token.idx + len(token.text)
        create_output(output, SYMBOL, token.text, (start, end))

    corporation_entities = list(filter(lambda ent: ent.label_ == CORP, doc.ents))

    for corporation_ent in corporation_entities:
        token = corporation_ent[0]
        start = token.idx
        end = token.idx + len(token.text)
        create_output(output, CORP, token.text, (start, end))

# %%
def find_events(doc, output):
    term_entities = list(filter(lambda ent: ent.label_ not in [SYMBOL, CORP], doc.ents))

    for term_ent in term_entities:
        token = term_ent[0]
        # print('------------')
        # print('token is: ', token.text)

        if token.dep_ == "compound:lvc":
            # print('parent is: ', token.head)
            if token.head.pos == VERB:
                # print('parent was a verb')
                # print('children of parent: ', list(token.head.children))
                subject = None
                for child in token.head.children:
                    if child.dep_ == "nsubj":
                        # print('Found a subject, outputing subtree of subject as subject')
                        subject, start_subj, end_subj = convert_subtree_to_str(child)
                        break
                    else:
                        print("NOT IMP - child dep is: ", child.dep_)
                        pass
                else:
                    print("didn't found any subj")
                    pass

                token_string, start, end = convert_subtree_to_str(token)
                end = token.head.idx + len(token.head.text)
                extracted_event = token_string + " " + token.head.text
                if subject:
                    create_output(
                        output,
                        token.ent_type_,
                        extracted_event,
                        (start, end),
                        subject=subject,
                        span_subject=(start_subj, end_subj),
                    )
                else:
                    create_output(
                        output, token.ent_type_, extracted_event, (start, end)
                    )
            else:
                extracted_event, start, end = convert_subtree_to_str(token)
                create_output(output, token.ent_type_, extracted_event, (start, end))

        elif token.dep_ == "nmod" or token.dep_ == "amod":
            # print('type is: ', token.dep_)
            # print('parent is: ', token.head)

            # print('finding parent that is not nmod or amod')
            main_noun = token
            ## print('1', main_noun, main_noun.dep_, main_noun.head.pos_)
            while (
                main_noun.dep_ == "nmod" or main_noun.dep_ == "amod"
            ) and main_noun.head.pos == NOUN:
                main_noun = main_noun.head
                ## print('2', main_noun, main_noun.dep_, main_noun.head.pos_)
            if main_noun.pos != NOUN:
                print("WARNING ------------------> check code in else: dep = nmod amod")
                continue

            # print('Found a Noun parent that is not nmod or amod')

            if main_noun.dep_ == "root":
                # print('Noun parent is root, text: ', main_noun.text)
                children = list(main_noun.children)
                # print('children are: ', children)
                # print('left chilren are: ', list(main_noun.lefts))
                # print('right chilren are: ', list(main_noun.rights))
                for child in children:
                    # print('child text: ', child.text, ' pos: ', child.pos_, ' dep_: ', child.dep_)
                    if child.dep_ == "cop" and child.pos == AUX:
                        extracted_event, start, end = get_root_string(main_noun)
                        create_output(
                            output, token.ent_type_, extracted_event, (start, end)
                        )
                        break
                else:
                    # TODO: this is of no use
                    extracted_event, start, end = get_root_string(main_noun)
                    create_output(
                        output, token.ent_type_, extracted_event, (start, end)
                    )

            else:
                extracted_event, start, end = convert_subtree_to_str(
                    main_noun, remove_ADP=True
                )
                # extracted_event, start, end = convert_subtree_to_str(main_noun, not_in=['ADP'])

                create_output(output, token.ent_type_, extracted_event, (start, end))

        elif token.dep_ == "root":
            extracted_event, start, end = get_root_string(token)
            create_output(output, token.ent_type_, extracted_event, (start, end))

        else:
            # print('type is: other')
            extracted_event, start, end = convert_subtree_to_str(token, remove_ADP=True)

            # print(text[start:end])
            create_output(output, token.ent_type_, extracted_event, (start, end))

# %%
def has_intersection(first, second):
    if first[0] < second[0]:
        if first[1] < second[0]:
            return False
        else:
            return True
    else:
        if first[0] > second[1]:
            return False
        else:
            return True


def combine(first, second, text):
    start = min(first["span"][0], second["span"][0])
    end = max(first["span"][1], second["span"][1])
    new_span = (start, end)
    new_marker = text[start:end]
    return new_span, new_marker


def remove_type_overlap(match_list, text):
    n = len(match_list)
    if n == 0:
        return []
    i = 0
    j = 1
    while i < n and j < n:
        first = match_list[i]
        second = match_list[j]
        if has_intersection(first["span"], second["span"]):
            new_span, new_marker = combine(first, second, text)
            match_list[i]["span"] = new_span
            match_list[i]["marker"] = new_marker
            match_list[j] = None
        else:
            i = j
        j += 1

    match_list = list(filter(lambda x: not x is None, match_list))
    return match_list


def remove_span_overlap(OUTPUT, text):
    for key in OUTPUT.keys():
        OUTPUT[key] = remove_type_overlap(OUTPUT[key], text)
    return OUTPUT


def print_output(OUTPUT, text):
    for key in OUTPUT.keys():
        for o in OUTPUT[key]:
            # print('----')
            # print(text[o['span'][0]:o['span'][1]])
            print(json.dumps(o, ensure_ascii=False, indent=2))

# %%
def run(*texts):
    for text_index, text in enumerate(texts):
        output = {
            SYMBOL: [],
            CORP: [],
            EVENT: [],
            ANNOUNCE: [],
            ANALYSE: [],
            CHARACTERS: [],
        }

        text = normalizer1.normalize(text)
        text = normalizer2.normalize(text)

        print(
            f"---------------------------- input {text_index}----------------------------------------------"
        )
        print(f"Normalized input: {text}")

        doc = stanza_nlp(text)

        doc = set_ents(symbols, corporations, doc, matcher, text)

        find_symbols_and_corporations(doc, output)

        find_events(doc, output)

        # print('Entities: ...')
        # displacy.render(doc, style='ent', jupyter=True)

        # print('Dependency Tree: ...')
        # displacy.render(doc, style='dep', jupyter=True)

        output = remove_span_overlap(output, text)
        print_output(output, text)

# %%
examples = [
    "برکت امروز اطلاعیه‌ای مهم منتشر میکند.",
    "نماد برکت امروز عرضه‌ی اولیه خیلی خوبی داره.",
    "نماد برکت امروز عرضه ی اولیه خیلی خوبی داره.",
    "نماد برکت امروز عرضه ی اولیه دارد.",
    "عرضه های اولیه امروز خوب هستند.",
    "عرضه اولیه‌های امروز خوب هستند.",
    "این عرضه‌ی اولیه خیلی خوبه",
    "رشد قیمت‌ها باعث ایجاد صف خرید در سهم پرشیا شد",
    "یک نکته‌ی تکنیکالی هم در صورت دستکاری نشدن اضافه کنم، کندلی که روز سه شنبه‌ی گذشته ثبت کرد کامل است",
    "آ س پ امروز روند مثبتی داشت.",
    "آمریکا موجب ریزش بازار شد",
    "ارزش سهام مخابرات ایران امروز کاهش زیادی یافت.‎",
    "قیمت سهام زیاد است. رشد قیمت‌ها باعث کاهش قیمت شد. ریزش بازار هم به همین دلیل بود.",
]


run(*examples)
# Out:
# ---------------------------- input 0----------------------------------------------
# Normalized input: برکت امروز اطلاعیه‌ای مهم منتشر میکند.
# {
#   "type": "نماد",
#   "marker": "برکت",
#   "span": [
#     0,
#     4
#   ]
# }
# {
#   "type": "اعلان",
#   "marker": "اطلاعیه‌ای مهم",
#   "span": [
#     11,
#     25
#   ]
# }
# ---------------------------- input 1----------------------------------------------
# Normalized input: نماد برکت امروز عرضه‌ی اولیه خیلی خوبی داره.
# {
#   "type": "نماد",
#   "marker": "برکت",
#   "span": [
#     5,
#     9
#   ]
# }
# {
#   "type": "واقعه",
#   "marker": "عرضه‌ی اولیه خوبی",
#   "span": [
#     16,
#     38
#   ]
# }
# ---------------------------- input 2----------------------------------------------
# Normalized input: نماد برکت امروز عرضه‌ی اولیه خیلی خوبی داره.
# {
#   "type": "نماد",
#   "marker": "برکت",
#   "span": [
#     5,
#     9
#   ]
# }
# {
#   "type": "واقعه",
#   "marker": "عرضه‌ی اولیه خوبی",
#   "span": [
#     16,
#     38
#   ]
# }
# ---------------------------- input 3----------------------------------------------
# Normalized input: نماد برکت امروز عرضه‌ی اولیه دارد.
# {
#   "type": "نماد",
#   "marker": "برکت",
#   "span": [
#     5,
#     9
#   ]
# }
# {
#   "type": "واقعه",
#   "marker": "عرضه‌ی اولیه",
#   "span": [
#     16,
#     28
#   ]
# }
# ---------------------------- input 4----------------------------------------------
# Normalized input: عرضه‌های اولیه امروز خوب هستند.
# {
#   "type": "واقعه",
#   "marker": "عرضه‌های اولیه",
#   "span": [
#     0,
#     14
#   ]
# }
# ---------------------------- input 5----------------------------------------------
# Normalized input: عرضه اولیه‌های امروز خوب هستند.
# {
#   "type": "واقعه",
#   "marker": "عرضه اولیه‌های امروز",
#   "span": [
#     0,
#     20
#   ]
# }
# ---------------------------- input 6----------------------------------------------
# Normalized input: این عرضه‌ی اولیه خیلی خوبه
# {
#   "type": "واقعه",
#   "marker": "این عرضه‌ی اولیه",
#   "span": [
#     0,
#     16
#   ]
# }
# ---------------------------- input 7----------------------------------------------
# Normalized input: رشد قیمت‌ها باعث ایجاد صف خرید در سهم پرشیا شد
# {
#   "type": "نماد",
#   "marker": "پرشیا",
#   "span": [
#     38,
#     43
#   ]
# }
# {
#   "type": "واقعه",
#   "marker": "رشد قیمت‌ها",
#   "span": [
#     0,
#     11
#   ]
# }
# {
#   "type": "واقعه",
#   "marker": "ایجاد صف خرید در سهم پرشیا",
#   "span": [
#     17,
#     43
#   ]
# }
# ---------------------------- input 8----------------------------------------------
# Normalized input: یک نکته‌ی تکنیکالی هم در صورت دستکاری نشدن اضافه کنم، کندلی که روز سه شنبه‌ی گذشته ثبت کرد کامل است
# {
#   "type": "تحلیل",
#   "marker": "یک نکته‌ی تکنیکالی",
#   "span": [
#     0,
#     18
#   ]
# }
# {
#   "type": "تحلیل",
#   "marker": "کندلی که روز سه شنبه‌ی گذشته ثبت کرد",
#   "span": [
#     54,
#     90
#   ]
# }
# ---------------------------- input 9----------------------------------------------
# Normalized input: آ س پ امروز روند مثبتی داشت.
# {
#   "type": "نماد",
#   "marker": "آ س پ",
#   "span": [
#     0,
#     5
#   ]
# }
# {
#   "type": "واقعه",
#   "marker": "روند مثبتی",
#   "span": [
#     12,
#     22
#   ]
# }
# ---------------------------- input 10----------------------------------------------
# Normalized input: آمریکا موجب ریزش بازار شد
# {
#   "type": "واقعه",
#   "marker": "ریزش بازار",
#   "span": [
#     12,
#     22
#   ]
# }
# ---------------------------- input 11----------------------------------------------
# Normalized input: ارزش سهام مخابرات ایران امروز کاهش زیادی یافت. ‎
# {
#   "type": "شرکت",
#   "marker": "مخابرات ایران",
#   "span": [
#     10,
#     23
#   ]
# }
# {
#   "type": "واقعه",
#   "marker": "کاهش زیادی یافت",
#   "span": [
#     30,
#     45
#   ],
#   "subject": "ارزش سهام مخابرات ایران",
#   "span_subject": [
#     0,
#     23
#   ]
# }
# ---------------------------- input 12----------------------------------------------
# Normalized input: قیمت سهام زیاد است. رشد قیمت‌ها باعث کاهش قیمت شد. ریزش بازار هم به همین دلیل بود.
# {
#   "type": "واقعه",
#   "marker": "رشد قیمت‌ها",
#   "span": [
#     20,
#     31
#   ]
# }
# {
#   "type": "واقعه",
#   "marker": "کاهش قیمت",
#   "span": [
#     37,
#     46
#   ]
# }
# {
#   "type": "واقعه",
#   "marker": "ریزش بازار",
#   "span": [
#     51,
#     61
#   ]
# }
